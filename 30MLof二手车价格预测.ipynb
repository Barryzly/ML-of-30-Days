# %% [markdown]
# ## Coggle 30 Days of ML-二手车交易价格预测

# %%
import pandas as pd

# %%
data1 = pd.read_csv('used_car_sample_submit.csv',sep=' ')
Train_data = pd.read_csv('used_car_train_20200313/used_car_train_20200313.csv', sep=' ')
Test_data = pd.read_csv('used_car_testB_20200421/used_car_testB_20200421.csv', sep=' ')
print(data1)
print("-------------------")
print(Train_data)
print("-------------------")
print(Test_data)
# Out:
#       SaleID,price
# 0         150000,0
# 1         150001,0
# 2         150002,0
# 3         150003,0
# 4         150004,0
# ...            ...
# 49995     199995,0
# 49996     199996,0
# 49997     199997,0
# 49998     199998,0
# 49999     199999,0
#
# [50000 rows x 1 columns]
# -------------------
#         SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  \
# 0            0     736  20040402   30.0      6       1.0       0.0      0.0
# 1            1    2262  20030301   40.0      1       2.0       0.0      0.0
# 2            2   14874  20040403  115.0     15       1.0       0.0      0.0
# 3            3   71865  19960908  109.0     10       0.0       0.0      1.0
# 4            4  111080  20120103  110.0      5       1.0       0.0      0.0
# ...        ...     ...       ...    ...    ...       ...       ...      ...
# 149995  149995  163978  20000607  121.0     10       4.0       0.0      1.0
# ...
